# %% [markdown]
# # Лабораторная работа №4 по теме "Байесовские сети"

# %% [markdown]
# ```
# Студент: Дорофеев Демид Сергеевич
# Группа: М8О-307Б-23
# Датасет: Mushroom Classification / Zoo Animal Classification
# ```

# %% [markdown]
# ```
# === Сроки сдачи ====
# > Оценка 5 28.11
# > Оценка 4 6.12
# > Оценка 3 до зачетной недели
# ```

# %% [markdown]
# #### Что посмотреть?
# * https://youtu.be/QYJBAKy9aCA?si=cujv1dtDalM2S0y-
# * https://www.youtube.com/watch?v=a_fQX4-PHTU
# * https://youtu.be/ivR1CWQkAMA?si=lW_7ug2CHEyg5IC0
# * https://youtu.be/DlSt-irw-uI?si=tNjaoFkMMCbEKa-3

# %% [markdown]
# ## Направление лабораторной работы
#
# Лабораторная работа посвящена изучению байесовских сетей **Bayesian Networks** с помощью библиотеки pgmpy. Студенты должны освоить загрузку и обработку данных, построение модели, оценку параметров, анализ вероятностных таблиц, визуализацию и дополнительные аспекты анализа. Работа выполняется на Python, с использованием библиотек *pandas, pgmpy, networkx и matplotlib*.
#
# ## Заданиe 1
#
# Выберите один из двух рекомендованных датасетов ([Mushroom Classification](https://www.kaggle.com/datasets/uciml/mushroom-classification) или [Zoo Animal Classification](https://www.kaggle.com/datasets/uciml/zoo-animal-classification)) для анализа. Постройте байесовскую сеть, моделирующую зависимости между переменными (например, в Mushroom: атрибуты вроде `odor` и `cap-color` влияют на `class` — съедобный/ядовитый; в Zoo: бинарные признаки вроде `hair` и `feathers` определяют класс животного).
#
# ## Функциональные требования
#
# **Обязательные требования:**
#
# * Используйте датасет с категориальными переменными (все данные в рекомендованных датасетах уже дискретные, но при необходимости примените label encoding или дискретизацию).
# * Определите структуру сети мануально (на основе логических зависимостей) или автоматически (с помощью HillClimbSearch).
# * Оцените параметры модели из данных.
# * Выполните анализ CPT и визуализацию.
# * Добавьте раздел с выводами: опишите, как сеть моделирует реальные зависимости в датасете (например, в Mushroom: как 'gill-color' коррелирует с токсичностью; в Zoo: как 'milk' указывает на млекопитающих).
# * Сдайте отчет в формате Jupyter Notebook или Python-скрипт с комментариями, включая код, выводы и визуализации.
# * Сравните результаты с baseline-моделью (например, наивный байесовский классификатор из scikit-learn) по метрикам accuracy или log-likelihood.
#
# ## Задание 2
#
# ### [Пример] Структура презентации для студентов по лабораторной работе "Bayesian Networks"
#
# #### 1. **Титульный слайд (1 слайд)**
#    - **Содержание**: Название работы ("Лабораторная работа: Bayesian Networks на примере датасета [Название датасета]"), имя студента/группы, дата, курс/предмет.
#    - **Почему важно**: Введение в тему, чтобы аудитория сразу поняла, о чём речь.
#    - **Совет студентам**: Добавьте логотип университета или релевантную картинку (например, схему Bayesian Network).
#
# #### 2. **Введение (1–2 слайда)**
#    - **Содержание**:
#      - Краткое определение Bayesian Networks: что это такое, зачем используются (моделирование вероятностных зависимостей, выводы на основе данных).
#      - Краткий обзор выбранного датасета (например, для Car Evaluation: описание атрибутов, размер, источник с Kaggle).
#    - **Почему важно**: Устанавливает контекст, напоминает теорию.
#    - **Совет студентам**: Используйте простой пример из жизни (например, "Bayesian Networks помогают предсказывать, стоит ли покупать машину на основе её характеристик"). Добавьте 1–2 формулы (например, $P(A|B) = P(B|A) P(A) / P(B)$) для напоминания.
#
# #### 3. **Загрузка и обработка датасета (2 слайда)**
#    - **Содержание**:
#      - Слайд 1: Как загружали данные (код с pd.read_csv, head() и статистика: shape, value_counts).
#      - Слайд 2: Обработка (label encoding, удаление дубликатов, дискретизация если была; покажите до/после в таблице).
#    - **Почему важно**: Показывает подготовку данных — основа любой ML-задачи.
#    - **Совет студентам**: Вставьте скриншоты кода и вывода из Jupyter/Colab. Объясните, почему обработка нужна (для pgmpy данные должны быть дискретными).
#
# #### 4. **Построение Bayesian Network (1–2 слайда)**
#    - **Содержание**:
#      - Описание структуры сети (мануальная или автоматическая с HillClimbSearch).
#      - Примеры ребёр (edges) и узлов (nodes).
#      - Код создания модели (from pgmpy.models import BayesianNetwork).
#
# #### 5. **Оценка параметров и CPT (2 слайда)**
#    - **Содержание**:
#      - Слайд 1: Как оценивали параметры (MaximumLikelihoodEstimator или BayesianEstimator; код model.fit).
#      - Слайд 2: Просмотр CPT (примеры таблиц для 2–3 узлов, код get_cpds).
#    - **Почему важно**: Показывает, как сеть "учится" на данных.
#    - **Совет студентам**: Выделите интересные вероятности (например, "Вероятность 'vgood' при высокой safety = 0.8"). Используйте таблицы для наглядности.
#
# #### 6. **Визуализация сети (1 слайд)**
#    - **Содержание**: Код визуализации (networkx, nx.draw) и полученный граф.
#    - **Почему важно**: Визуалы помогают понять структуру.
#    - **Совет студентам**: Вставьте изображение графа. Обсудите, что видно (направления стрелок — зависимости).
#
# #### 7. **Inference и результаты (2 слайда)**
#    - **Содержание**:
#      - Слайд 1: Как выполняли inference (VariableElimination, query с evidence).
#      - Слайд 2: Примеры сценариев (2–3, например, вероятность класса при заданных атрибутах) и сравнение с baseline (majority class).
#    - **Почему важно**: Показывает практическое применение сети.
#    - **Совет студентам**: Приведите числовые результаты в таблице или графике. Обсудите, что это значит (например, "Модель предсказывает лучше, чем случайный выбор").
#
# #### 8. **Оценка с Baseline (1 слайд)**
#  - Показать что лучше и сравнить

# %% [markdown]
# ## Пример работы

# %% [markdown]
# ### 0. Установка зависимостей

# %%
# !pip install pgmpy
# !pip install networkx
# !pip install matplotlib
# !pip install pandas 
# !pip install kagglehub
# Out:
# Requirement already satisfied: pgmpy in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.0.0)
# Requirement already satisfied: networkx in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pgmpy) (3.5)
# Requirement already satisfied: numpy in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pgmpy) (2.2.6)
# Requirement already satisfied: scipy in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pgmpy) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pgmpy) (1.7.2)
# Requirement already satisfied: pandas in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pgmpy) (2.3.3)
# Requirement already satisfied: torch in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pgmpy) (2.9.1)
# Requirement already satisfied: statsmodels in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pgmpy) (0.14.5)
# Requirement already satisfied: tqdm in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pgmpy) (4.67.1)
# Requirement already satisfied: joblib in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pgmpy) (1.5.2)
# Requirement already satisfied: opt-einsum in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pgmpy) (3.4.0)
# Requirement already satisfied: pyro-ppl in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pgmpy) (1.9.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas->pgmpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas->pgmpy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas->pgmpy) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas->pgmpy) (1.17.0)
# Requirement already satisfied: pyro-api>=0.1.1 in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyro-ppl->pgmpy) (0.1.2)
# Requirement already satisfied: filelock in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch->pgmpy) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch->pgmpy) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch->pgmpy) (1.14.0)
# Requirement already satisfied: jinja2 in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch->pgmpy) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch->pgmpy) (2025.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sympy>=1.13.3->torch->pgmpy) (1.3.0)
# Requirement already satisfied: colorama in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm->pgmpy) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jinja2->torch->pgmpy) (3.0.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn->pgmpy) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from statsmodels->pgmpy) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\justdema\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from statsmodels->pgmpy) (25.0)
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: C:\Users\JustDema\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ### 1. Загружаем датасет на прямую с KuggleHub

# %%
import kagglehub
import pandas as pd
from pathlib import Path

path = Path(kagglehub.dataset_download("uciml/mushroom-classification"))
print("Path to dataset files:", path)


feature_names = ['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises',
                          'odor', 'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
                          'stalk-shape','stalk-root','stalk-surface-above-ring','stalk-surface-below-ring','stalk-color-above-ring',
                          'stalk-color-below-ring','veil-type','veil-color','ring-number','ring-type',
                          'spore-print-color','population','habitat'
                          ],


file_dir = path / 'mushrooms.csv'
data = pd.read_csv(file_dir, header=None,
                   names=['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises',
                          'odor', 'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
                          'stalk-shape','stalk-root','stalk-surface-above-ring','stalk-surface-below-ring','stalk-color-above-ring',
                           'stalk-color-below-ring','veil-type','veil-color','ring-number','ring-type',
                          'spore-print-color','population','habitat'
                          ],
                   )

data = data.drop(0)

RND_SEED=7123654

data.shape, data.size   # Размер датасета
# Out:
# Path to dataset files: C:\Users\JustDema\.cache\kagglehub\datasets\uciml\mushroom-classification\versions\1
# ((8124, 23), 186852)

# %% [markdown]
# Посмотрим на его структуру

# %%
data.iloc[:,:8].head(3)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 1     p         x           s         n       t    p               f
# 2     e         x           s         y       t    a               f
# 3     e         b           s         w       t    l               f
#
#   gill-spacing
# 1            c
# 2            c
# 3            c

# %%
data.iloc[:,8:16].head(3)
# Out:
#   gill-size gill-color stalk-shape stalk-root stalk-surface-above-ring  \
# 1         n          k           e          e                        s
# 2         b          k           e          c                        s
# 3         b          n           e          c                        s
#
#   stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring
# 1                        s                      w                      w
# 2                        s                      w                      w
# 3                        s                      w                      w

# %%
data.iloc[:,16:].head(3)
# Out:
#   veil-type veil-color ring-number ring-type spore-print-color population  \
# 1         p          w           o         p                 k          s
# 2         p          w           o         p                 n          n
# 3         p          w           o         p                 n          n
#
#   habitat
# 1       u
# 2       g
# 3       m

# %%
# data["gill-color"].unique()

# %%
data.shape
# Out:
# (8124, 23)

# %% [markdown]
# ### 2. Обработка датасета

# %% [markdown]
# можно закодировать метки с помощью Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

label_encoders = {}
mappings = {}

for col in data.columns:
    le = LabelEncoder()
    original_values = data[col].unique()
    data[col] = le.fit_transform(data[col])
    label_encoders[col] = le
    mappings[col] = dict(zip(le.classes_, le.transform(le.classes_)))

for col, mapping in mappings.items():
    print(f"Столбец '{col}':")
    for value, encoded in mapping.items():
        print(f"  {value} -> {encoded}")
    print()

data.head(5)
# Out:
# Столбец 'class':
#   e -> 0
#   p -> 1
#
# Столбец 'cap-shape':
#   b -> 0
#   c -> 1
#   f -> 2
#   k -> 3
#   s -> 4
#   x -> 5
#
# Столбец 'cap-surface':
#   f -> 0
#   g -> 1
#   s -> 2
#   y -> 3
#
# Столбец 'cap-color':
#   b -> 0
#   c -> 1
#   e -> 2
#   g -> 3
#   n -> 4
#   p -> 5
#   r -> 6
#   u -> 7
#   w -> 8
#   y -> 9
#
# Столбец 'bruises':
#   f -> 0
#   t -> 1
#
# Столбец 'odor':
#   a -> 0
#   c -> 1
#   f -> 2
#   l -> 3
#   m -> 4
#   n -> 5
#   p -> 6
#   s -> 7
#   y -> 8
#
# Столбец 'gill-attachment':
#   a -> 0
#   f -> 1
#
# Столбец 'gill-spacing':
#   c -> 0
#   w -> 1
#
# Столбец 'gill-size':
#   b -> 0
#   n -> 1
#
# Столбец 'gill-color':
#   b -> 0
#   e -> 1
#   g -> 2
#   h -> 3
#   k -> 4
#   n -> 5
#   o -> 6
#   p -> 7
#   r -> 8
#   u -> 9
#   w -> 10
#   y -> 11
#
# Столбец 'stalk-shape':
#   e -> 0
#   t -> 1
#
# Столбец 'stalk-root':
#   ? -> 0
#   b -> 1
#   c -> 2
#   e -> 3
#   r -> 4
#
# Столбец 'stalk-surface-above-ring':
#   f -> 0
#   k -> 1
#   s -> 2
#   y -> 3
#
# Столбец 'stalk-surface-below-ring':
#   f -> 0
#   k -> 1
#   s -> 2
#   y -> 3
#
# Столбец 'stalk-color-above-ring':
#   b -> 0
#   c -> 1
#   e -> 2
#   g -> 3
#   n -> 4
#   o -> 5
#   p -> 6
#   w -> 7
#   y -> 8
#
# Столбец 'stalk-color-below-ring':
#   b -> 0
#   c -> 1
#   e -> 2
#   g -> 3
#   n -> 4
#   o -> 5
#   p -> 6
#   w -> 7
#   y -> 8
#
# Столбец 'veil-type':
#   p -> 0
#
# Столбец 'veil-color':
#   n -> 0
#   o -> 1
#   w -> 2
#   y -> 3
#
# Столбец 'ring-number':
#   n -> 0
#   o -> 1
#   t -> 2
#
# Столбец 'ring-type':
#   e -> 0
#   f -> 1
#   l -> 2
#   n -> 3
#   p -> 4
#
# Столбец 'spore-print-color':
#   b -> 0
#   h -> 1
#   k -> 2
#   n -> 3
#   o -> 4
#   r -> 5
#   u -> 6
#   w -> 7
#   y -> 8
#
# Столбец 'population':
#   a -> 0
#   c -> 1
#   n -> 2
#   s -> 3
#   v -> 4
#   y -> 5
#
# Столбец 'habitat':
#   d -> 0
#   g -> 1
#   l -> 2
#   m -> 3
#   p -> 4
#   u -> 5
#   w -> 6
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 1      1          5            2          4        1     6                1
# 2      0          5            2          9        1     0                1
# 3      0          0            2          8        1     3                1
# 4      1          5            3          8        1     6                1
# 5      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 1             0          1           4  ...                         2
# 2             0          0           4  ...                         2
# 3             0          0           5  ...                         2
# 4             0          1           5  ...                         2
# 5             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 1                       7                       7          0           2
# 2                       7                       7          0           2
# 3                       7                       7          0           2
# 4                       7                       7          0           2
# 5                       7                       7          0           2
#
#    ring-number  ring-type  spore-print-color  population  habitat
# 1            1          4                  2           3        5
# 2            1          4                  3           2        1
# 3            1          4                  3           2        3
# 4            1          4                  2           3        5
# 5            1          0                  3           0        1
#
# [5 rows x 23 columns]

# %%
# data["gill-color"].unique()

# %% [markdown]
# можно соханить как категориальный, но удаляем дубликаты

# %%
# data = data.drop_duplicates()
# print(data.shape)

# %% [markdown]
# ❗️**так же если данные НЕПРЕРЫВНЫ, то нужно их дискретизировать**❗️

# %% [markdown]
# ### 3. Построение Байесовсой сети

# %% [markdown]
# Данный метод представляет собой конструктивное построение структуры дискретной байесовской сети путем явного задания направленных ребер между узлами. В этом подходе структура сети создается декларативно - мы напрямую указываем список кортежей (родительский узел, дочерний узел), что определяет направленные зависимости между переменными.

# %%
from pgmpy.models import DiscreteBayesianNetwork

# Задаем направление между вершинами

network = [
     ('class', 'cap-shape'),
     ('class', 'cap-surface'),
     ('class', 'cap-color'),
     ('class', 'bruises'),
     ('class', 'odor'),
     ('class', 'gill-attachment'),
     ('class', 'gill-spacing'),
     ('class', 'gill-size'),
     ('class', 'gill-color'),
     ('class', 'stalk-shape'),
     ('class', 'stalk-root'),
     ('class', 'stalk-surface-above-ring'),
     ('class', 'stalk-surface-below-ring'),
     ('class', 'stalk-color-above-ring'),
     ('class', 'stalk-color-below-ring'),
     ('class', 'veil-type'),
     ('class', 'veil-color'),
     ('class', 'ring-number'),
     ('class', 'ring-type'),
     ('class', 'spore-print-color'),
     ('class', 'population'),
     ('class', 'habitat'),
]


# 1 случай: P(class | признаки) ∝ P(class) × ∏ P(признак_i | class)
# 2 случай: P(class | признаки) = таблица размером states[class] × states[признак_1] × ... × states[признак_22] 


# network = [
#     ('cap-shape', 'class'),
#     ('cap-surface', 'class'),
#     ('cap-color', 'class'),
#     ('bruises', 'class'),
#     ('odor', 'class'),
#     ('gill-attachment', 'class'),
#     ('gill-spacing', 'class'),
#     ('gill-size', 'class'),
#     ('gill-color', 'class'),
#     ('stalk-shape', 'class'),
#     ('stalk-root', 'class'),
#     ('stalk-surface-above-ring', 'class'),
#     ('stalk-surface-below-ring', 'class'),
#     ('stalk-color-above-ring', 'class'),
#     ('stalk-color-below-ring', 'class'),
#     ('veil-type', 'class'),
#     ('veil-color', 'class'),
#     ('ring-number', 'class'),
#     ('ring-type', 'class'),
#     ('spore-print-color', 'class'),
#     ('population', 'class'),
#     ('habitat', 'class'),
# ]

# Строим Дискретную Байесовскую сеть
model_h_m = DiscreteBayesianNetwork(network)
model_h_b = DiscreteBayesianNetwork(network)
model_h_m.edges()  # Просмотр ребер
# Out:
# OutEdgeView([('class', 'cap-shape'), ('class', 'cap-surface'), ('class', 'cap-color'), ('class', 'bruises'), ('class', 'odor'), ('class', 'gill-attachment'), ('class', 'gill-spacing'), ('class', 'gill-size'), ('class', 'gill-color'), ('class', 'stalk-shape'), ('class', 'stalk-root'), ('class', 'stalk-surface-above-ring'), ('class', 'stalk-surface-below-ring'), ('class', 'stalk-color-above-ring'), ('class', 'stalk-color-below-ring'), ('class', 'veil-type'), ('class', 'veil-color'), ('class', 'ring-number'), ('class', 'ring-type'), ('class', 'spore-print-color'), ('class', 'population'), ('class', 'habitat')])

# %% [markdown]
# Этот код использует метод поиска с подъемом на холм (Hill Climb Search) для оценки структуры Байесовской сети из данных, используя Байесовский информационный критерий (BIC) в качестве функции оценки.
#
# BIC (Bayesian Information Criterion) — это функция оценки, используемая для сравнения статистических моделей (в данном случае, структур Байесовских сетей).
#
# Цель: Он наказывает модели за излишнюю сложность (большое количество параметров/ребер), одновременно вознаграждая за хорошее соответствие данным.
#
# Принцип: Модели с меньшим значением BIC считаются лучшими.
#
# Формула (концептуально): BIC≈L−k⋅ln(N), где L — логарифмическое правдоподобие модели (насколько хорошо модель объясняет данные), k — количество параметров модели (сложность), а N — количество точек данных.
#
# ❗️**ЕСЛИ будете строить сеть автоматически, посмотрите на методы и разберитесь с ними☺️**❗️

# %%
from sklearn.model_selection import train_test_split

X = data.drop(columns=['class'])
y = data['class']

# Разделение выборки на test/train (20/80)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=RND_SEED
)

# %%
from pgmpy.estimators import HillClimbSearch, BIC
import numpy as np

data_train = pd.DataFrame(X_train, columns=['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises',
                          'odor', 'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
                          'stalk-shape','stalk-root','stalk-surface-above-ring','stalk-surface-below-ring','stalk-color-above-ring',
                          'stalk-color-below-ring','veil-type','veil-color','ring-number','ring-type',
                          'spore-print-color','population','habitat'
                          ],)
data_train['class'] = y_train.values  # или просто y_train


hc = HillClimbSearch(data_train)
best_model = hc.estimate(scoring_method=BIC(data_train))
model_a_m = DiscreteBayesianNetwork(best_model.edges())
model_a_b = DiscreteBayesianNetwork(best_model.edges())
model_a_m.edges()  # Автоматическая структура
# Out:
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'class': 'N', 'cap-shape': 'N', 'cap-surface': 'N', 'cap-color': 'N', 'bruises': 'N', 'odor': 'N', 'gill-attachment': 'N', 'gill-spacing': 'N', 'gill-size': 'N', 'gill-color': 'N', 'stalk-shape': 'N', 'stalk-root': 'N', 'stalk-surface-above-ring': 'N', 'stalk-surface-below-ring': 'N', 'stalk-color-above-ring': 'N', 'stalk-color-below-ring': 'N', 'veil-type': 'N', 'veil-color': 'N', 'ring-number': 'N', 'ring-type': 'N', 'spore-print-color': 'N', 'population': 'N', 'habitat': 'N'}
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'class': 'N', 'cap-shape': 'N', 'cap-surface': 'N', 'cap-color': 'N', 'bruises': 'N', 'odor': 'N', 'gill-attachment': 'N', 'gill-spacing': 'N', 'gill-size': 'N', 'gill-color': 'N', 'stalk-shape': 'N', 'stalk-root': 'N', 'stalk-surface-above-ring': 'N', 'stalk-surface-below-ring': 'N', 'stalk-color-above-ring': 'N', 'stalk-color-below-ring': 'N', 'veil-type': 'N', 'veil-color': 'N', 'ring-number': 'N', 'ring-type': 'N', 'spore-print-color': 'N', 'population': 'N', 'habitat': 'N'}
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'class': 'N', 'cap-shape': 'N', 'cap-surface': 'N', 'cap-color': 'N', 'bruises': 'N', 'odor': 'N', 'gill-attachment': 'N', 'gill-spacing': 'N', 'gill-size': 'N', 'gill-color': 'N', 'stalk-shape': 'N', 'stalk-root': 'N', 'stalk-surface-above-ring': 'N', 'stalk-surface-below-ring': 'N', 'stalk-color-above-ring': 'N', 'stalk-color-below-ring': 'N', 'veil-type': 'N', 'veil-color': 'N', 'ring-number': 'N', 'ring-type': 'N', 'spore-print-color': 'N', 'population': 'N', 'habitat': 'N'}
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# OutEdgeView([('class', 'habitat'), ('class', 'stalk-color-below-ring'), ('class', 'stalk-root'), ('class', 'stalk-surface-above-ring'), ('class', 'population'), ('class', 'veil-color'), ('habitat', 'ring-number'), ('stalk-color-below-ring', 'stalk-color-above-ring'), ('stalk-root', 'population'), ('stalk-root', 'habitat'), ('stalk-root', 'stalk-surface-below-ring'), ('stalk-root', 'cap-shape'), ('stalk-root', 'cap-surface'), ('stalk-root', 'ring-number'), ('population', 'gill-spacing'), ('population', 'cap-surface'), ('cap-color', 'odor'), ('cap-color', 'stalk-shape'), ('cap-color', 'bruises'), ('odor', 'class'), ('odor', 'spore-print-color'), ('odor', 'gill-spacing'), ('odor', 'stalk-shape'), ('odor', 'gill-size'), ('stalk-shape', 'spore-print-color'), ('stalk-shape', 'gill-color'), ('stalk-shape', 'stalk-color-below-ring'), ('stalk-shape', 'stalk-root'), ('stalk-shape', 'stalk-color-above-ring'), ('stalk-shape', 'ring-type'), ('stalk-shape', 'class'), ('stalk-shape', 'gill-size'), ('bruises', 'odor'), ('bruises', 'stalk-root'), ('bruises', 'habitat'), ('bruises', 'population'), ('bruises', 'stalk-shape'), ('bruises', 'gill-color'), ('gill-color', 'gill-size'), ('spore-print-color', 'gill-color'), ('spore-print-color', 'stalk-root'), ('spore-print-color', 'ring-type'), ('gill-spacing', 'ring-type'), ('gill-spacing', 'stalk-surface-above-ring'), ('gill-spacing', 'habitat'), ('gill-size', 'population'), ('gill-size', 'cap-shape'), ('gill-attachment', 'veil-color'), ('ring-type', 'stalk-color-below-ring'), ('ring-type', 'stalk-surface-below-ring'), ('ring-type', 'stalk-surface-above-ring'), ('stalk-color-above-ring', 'gill-attachment')])

# %% [markdown]
# ### 3. Получение вероятностей
#
# Мы хотим получить вероятностные оценки переходов из одного состояние в другое. Для этого необходимо Байесовскую сеть подогнать по данные и получить таблички (CPT).
#
# Conditional Probability Table (CPT) [Таблица Условных Вероятностей (CPT)] — это ключевой элемент, определяющий параметры Байесовской сети.
#
# * Что это: Это таблица, которая содержит вероятность каждого возможного состояния узла (переменной) при условии всех возможных комбинаций состояний его родительских узлов (тех, от которых к нему идут стрелки/ребра).
# * Роль: CPTs количественно определяют зависимости и силу связей между переменными, позволяя сети выполнять логический вывод и прогнозирование.
# * Простой пример: В CPT для узла "Кашель", родительским узлом которого является "Грипп", будет указана вероятность кашля, если грипп есть (например, 90%), и вероятность кашля, если гриппа нет (например, 5%).
#
# Чтобы получить значения вероятности переходов из разных узлов, нужно оценить эти вероятности. `HillClimbSearch` ищет только структуру, а `MaximumLikelihoodEstimator` и `BayesianEstimator` позволяют оценить вероятность.

# %%
# Метод Максимального Правдоподобия
from pgmpy.estimators import MaximumLikelihoodEstimator

model_h_m.fit(data_train, estimator=MaximumLikelihoodEstimator)
model_a_m.fit(data_train, estimator=MaximumLikelihoodEstimator)
# Out:
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'class': 'N', 'cap-shape': 'N', 'cap-surface': 'N', 'cap-color': 'N', 'bruises': 'N', 'odor': 'N', 'gill-attachment': 'N', 'gill-spacing': 'N', 'gill-size': 'N', 'gill-color': 'N', 'stalk-shape': 'N', 'stalk-root': 'N', 'stalk-surface-above-ring': 'N', 'stalk-surface-below-ring': 'N', 'stalk-color-above-ring': 'N', 'stalk-color-below-ring': 'N', 'veil-type': 'N', 'veil-color': 'N', 'ring-number': 'N', 'ring-type': 'N', 'spore-print-color': 'N', 'population': 'N', 'habitat': 'N'}
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'class': 'N', 'cap-shape': 'N', 'cap-surface': 'N', 'cap-color': 'N', 'bruises': 'N', 'odor': 'N', 'gill-attachment': 'N', 'gill-spacing': 'N', 'gill-size': 'N', 'gill-color': 'N', 'stalk-shape': 'N', 'stalk-root': 'N', 'stalk-surface-above-ring': 'N', 'stalk-surface-below-ring': 'N', 'stalk-color-above-ring': 'N', 'stalk-color-below-ring': 'N', 'veil-type': 'N', 'veil-color': 'N', 'ring-number': 'N', 'ring-type': 'N', 'spore-print-color': 'N', 'population': 'N', 'habitat': 'N'}

# %% [markdown]
# Вместо того чтобы просто считать частоты (как MLE), Байесовский оценщик вычисляет апостериорное распределение вероятностей (CPT)

# %%
# Байесовский оценщик
from pgmpy.estimators import BayesianEstimator

model_h_b.fit(data_train, estimator=BayesianEstimator,
              prior_type='BDeu', equivalent_sample_size=10)
model_a_b.fit(data_train, estimator=BayesianEstimator,
              prior_type='BDeu', equivalent_sample_size=10)
# Out:
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'class': 'N', 'cap-shape': 'N', 'cap-surface': 'N', 'cap-color': 'N', 'bruises': 'N', 'odor': 'N', 'gill-attachment': 'N', 'gill-spacing': 'N', 'gill-size': 'N', 'gill-color': 'N', 'stalk-shape': 'N', 'stalk-root': 'N', 'stalk-surface-above-ring': 'N', 'stalk-surface-below-ring': 'N', 'stalk-color-above-ring': 'N', 'stalk-color-below-ring': 'N', 'veil-type': 'N', 'veil-color': 'N', 'ring-number': 'N', 'ring-type': 'N', 'spore-print-color': 'N', 'population': 'N', 'habitat': 'N'}
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'class': 'N', 'cap-shape': 'N', 'cap-surface': 'N', 'cap-color': 'N', 'bruises': 'N', 'odor': 'N', 'gill-attachment': 'N', 'gill-spacing': 'N', 'gill-size': 'N', 'gill-color': 'N', 'stalk-shape': 'N', 'stalk-root': 'N', 'stalk-surface-above-ring': 'N', 'stalk-surface-below-ring': 'N', 'stalk-color-above-ring': 'N', 'stalk-color-below-ring': 'N', 'veil-type': 'N', 'veil-color': 'N', 'ring-number': 'N', 'ring-type': 'N', 'spore-print-color': 'N', 'population': 'N', 'habitat': 'N'}

# %% [markdown]
# Просмотр полной таблички

# %%
cpt_class_h_m = model_h_m.get_cpds('class')
cpt_class_h_b = model_h_b.get_cpds('class')
print("MaximumLikelihoodEstimator by hand")
print(cpt_class_h_m)
print("BayesianEstimator by hand")
print(cpt_class_h_b)

cpt_class_a_m = model_a_m.get_cpds('class')
cpt_class_a_b = model_a_b.get_cpds('class')
print("MaximumLikelihoodEstimator automatic")
print(cpt_class_a_m)
print("BayesianEstimator automatic")
print(cpt_class_a_b)
# Out:
# MaximumLikelihoodEstimator by hand
# +----------+----------+
# | class(0) | 0.514541 |
# +----------+----------+
# | class(1) | 0.485459 |
# +----------+----------+
# BayesianEstimator by hand
# +----------+----------+
# | class(0) | 0.514518 |
# +----------+----------+
# | class(1) | 0.485482 |
# +----------+----------+
# MaximumLikelihoodEstimator automatic
# +-------------+----------------+-----+----------------+----------------+
# | odor        | odor(0)        | ... | odor(8)        | odor(8)        |
# +-------------+----------------+-----+----------------+----------------+
# | stalk-shape | stalk-shape(0) | ... | stalk-shape(0) | stalk-shape(1) |
# +-------------+----------------+-----+----------------+----------------+
# | class(0)    | 1.0            | ... | 0.5            | 0.0            |
# +-------------+----------------+-----+----------------+----------------+
# | class(1)    | 0.0            | ... | 0.5            | 1.0            |
# +-------------+----------------+-----+----------------+----------------+
# BayesianEstimator automatic
# +-------------+-----+----------------------+
# | odor        | ... | odor(8)              |
# +-------------+-----+----------------------+
# | stalk-shape | ... | stalk-shape(1)       |
# +-------------+-----+----------------------+
# | class(0)    | ... | 0.000590318772136954 |
# +-------------+-----+----------------------+
# | class(1)    | ... | 0.9994096812278631   |
# +-------------+-----+----------------------+

# %% [markdown]
# Просмотр таблиц для конкретных узлов

# %%
for node in ['cap-color', 'ring-type', 'odor']:
    cpt = model_h_m.get_cpds(node)
    print(f"CPT for {node}:\n{cpt}")
# Out:
# CPT for cap-color:
# +--------------+----------------------+----------------------+
# | class        | class(0)             | class(1)             |
# +--------------+----------------------+----------------------+
# | cap-color(0) | 0.012260765550239234 | 0.03137876386687797  |
# +--------------+----------------------+----------------------+
# | cap-color(1) | 0.007476076555023923 | 0.001901743264659271 |
# +--------------+----------------------+----------------------+
# | cap-color(2) | 0.1513157894736842   | 0.22155309033280507  |
# +--------------+----------------------+----------------------+
# | cap-color(3) | 0.24222488038277512  | 0.2076069730586371   |
# +--------------+----------------------+----------------------+
# | cap-color(4) | 0.3005382775119617   | 0.2595879556259905   |
# +--------------+----------------------+----------------------+
# | cap-color(5) | 0.01375598086124402  | 0.021870047543581617 |
# +--------------+----------------------+----------------------+
# | cap-color(6) | 0.004186602870813397 | 0.0                  |
# +--------------+----------------------+----------------------+
# | cap-color(7) | 0.004186602870813397 | 0.0                  |
# +--------------+----------------------+----------------------+
# | cap-color(8) | 0.17045454545454544  | 0.07416798732171156  |
# +--------------+----------------------+----------------------+
# | cap-color(9) | 0.09360047846889952  | 0.1819334389857369   |
# +--------------+----------------------+----------------------+
# CPT for ring-type:
# +--------------+----------------------+----------------------+
# | class        | class(0)             | class(1)             |
# +--------------+----------------------+----------------------+
# | ring-type(0) | 0.24013157894736842  | 0.4469096671949287   |
# +--------------+----------------------+----------------------+
# | ring-type(1) | 0.012260765550239234 | 0.0                  |
# +--------------+----------------------+----------------------+
# | ring-type(2) | 0.0                  | 0.3416798732171157   |
# +--------------+----------------------+----------------------+
# | ring-type(3) | 0.0                  | 0.007606973058637084 |
# +--------------+----------------------+----------------------+
# | ring-type(4) | 0.7476076555023924   | 0.20380348652931854  |
# +--------------+----------------------+----------------------+
# CPT for odor:
# +---------+---------------------+----------------------+
# | class   | class(0)            | class(1)             |
# +---------+---------------------+----------------------+
# | odor(0) | 0.08941387559808613 | 0.0                  |
# +---------+---------------------+----------------------+
# | odor(1) | 0.0                 | 0.04817749603803487  |
# +---------+---------------------+----------------------+
# | odor(2) | 0.0                 | 0.5496038034865293   |
# +---------+---------------------+----------------------+
# | odor(3) | 0.09659090909090909 | 0.0                  |
# +---------+---------------------+----------------------+
# | odor(4) | 0.0                 | 0.007606973058637084 |
# +---------+---------------------+----------------------+
# | odor(5) | 0.8139952153110048  | 0.030110935023771792 |
# +---------+---------------------+----------------------+
# | odor(6) | 0.0                 | 0.0652931854199683   |
# +---------+---------------------+----------------------+
# | odor(7) | 0.0                 | 0.1502377179080824   |
# +---------+---------------------+----------------------+
# | odor(8) | 0.0                 | 0.14896988906497624  |
# +---------+---------------------+----------------------+

# %% [markdown]
# ### 4. Визуализация сети через библиотеку `networkx`

# %%
import networkx as nx
import matplotlib.pyplot as plt

nx_graph = nx.DiGraph(model_h_m.edges())
pos = nx.spring_layout(nx_graph, gravity=2)

plt.figure(figsize=(12, 8))

nx.draw(nx_graph, pos, with_labels=True, node_size=1200, node_color='cyan', arrows=True)
plt.title("Bayesian Network for MaximumLikelihoodEstimator by hand")
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

nx_graph = nx.DiGraph(model_h_b.edges())
pos = nx.spring_layout(nx_graph, gravity=2)

plt.figure(figsize=(12, 8))

nx.draw(nx_graph, pos, with_labels=True, node_size=1200, node_color='cyan', arrows=True)
plt.title("Bayesian Network for BayesianEstimator by hand")
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

nx_graph = nx.DiGraph(model_a_m.edges())
pos = nx.spring_layout(nx_graph, gravity=1)

plt.figure(figsize=(12, 8))

nx.draw(nx_graph, pos, with_labels=True, node_size=800, node_color='cyan', arrows=True)
plt.title("Bayesian Network for MaximumLikelihoodEstimator automatic")
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

nx_graph = nx.DiGraph(model_a_b.edges())
pos = nx.spring_layout(nx_graph, gravity=1)

plt.figure(figsize=(12, 8))

nx.draw(nx_graph, pos, with_labels=True, node_size=1200, node_color='cyan', arrows=True)
plt.title("Bayesian Network for BayesianEstimator automatic")
plt.show()

# %%
data['gill-color'].value_counts()
# Out:
# gill-color
# 0     1728
# 7     1492
# 10    1202
# 5     1048
# 2      752
# 3      732
# 9      492
# 4      408
# 1       96
# 11      86
# 6       64
# 8       24
# Name: count, dtype: int64

# %% [markdown]
# ### 5. Посмотрим пример инференса

# %%
from pgmpy.inference import VariableElimination

# black,brown,gray,pink,white,chocolate,purple,red,buff,green,yellow,orange,
# ['k' , 'n' , 'g', 'p', 'w' ,    'h'  ,  'u' ,'e', 'b', 'r' ,  'y' ,  'o' ]
# [ 4  ,  5  ,  2 ,  7 , 10  ,     3   ,   9  , 1 ,  0 ,  8  ,  11  ,   6  ]

infer = VariableElimination(model_h_m)
query = infer.query(variables=['class'], evidence={'gill-color': 0})
print("buff gill-color")
print(query)
query = infer.query(variables=['class'], evidence={'gill-color': 1})
print("red gill-color")
print(query)
query = infer.query(variables=['class'], evidence={'gill-color': 2})
print("gray gill-color")
print(query)
query = infer.query(variables=['class'], evidence={'gill-color': 3})
print("chocolate gill-color")
print(query)
# Out:
# buff gill-color
# +----------+--------------+
# | class    |   phi(class) |
# +==========+==============+
# | class(0) |       0.0000 |
# +----------+--------------+
# | class(1) |       1.0000 |
# +----------+--------------+
# red gill-color
# +----------+--------------+
# | class    |   phi(class) |
# +==========+==============+
# | class(0) |       1.0000 |
# +----------+--------------+
# | class(1) |       0.0000 |
# +----------+--------------+
# gray gill-color
# +----------+--------------+
# | class    |   phi(class) |
# +==========+==============+
# | class(0) |       0.3234 |
# +----------+--------------+
# | class(1) |       0.6766 |
# +----------+--------------+
# chocolate gill-color
# +----------+--------------+
# | class    |   phi(class) |
# +==========+==============+
# | class(0) |       0.2774 |
# +----------+--------------+
# | class(1) |       0.7226 |
# +----------+--------------+

# %%
from pgmpy.inference import VariableElimination

# black,brown,gray,pink,white,chocolate,purple,red,buff,green,yellow,orange,
# ['k' , 'n' , 'g', 'p', 'w' ,    'h'  ,  'u' ,'e', 'b', 'r' ,  'y' ,  'o' ]
# [ 4  ,  5  ,  2 ,  7 , 10  ,     3   ,   9  , 1 ,  0 ,  8  ,  11  ,   6  ]

infer = VariableElimination(model_h_m)
query = infer.query(variables=['class'], evidence={'gill-color': 2})
print("model_h_m")
print(query)
infer = VariableElimination(model_h_b)
query = infer.query(variables=['class'], evidence={'gill-color': 2})
print("model_h_b")
print(query)
infer = VariableElimination(model_a_m)
query = infer.query(variables=['class'], evidence={'gill-color': 2})
print("model_a_m")
print(query)
infer = VariableElimination(model_a_b)
query = infer.query(variables=['class'], evidence={'gill-color': 2})
print("model_a_b")
print(query)
# Out:
# model_h_m
# +----------+--------------+
# | class    |   phi(class) |
# +==========+==============+
# | class(0) |       0.3234 |
# +----------+--------------+
# | class(1) |       0.6766 |
# +----------+--------------+
# model_h_b
# +----------+--------------+
# | class    |   phi(class) |
# +==========+==============+
# | class(0) |       0.3236 |
# +----------+--------------+
# | class(1) |       0.6764 |
# +----------+--------------+
# model_a_m
# +----------+--------------+
# | class    |   phi(class) |
# +==========+==============+
# | class(0) |       0.2880 |
# +----------+--------------+
# | class(1) |       0.7120 |
# +----------+--------------+
# model_a_b
# +----------+--------------+
# | class    |   phi(class) |
# +==========+==============+
# | class(0) |       0.2887 |
# +----------+--------------+
# | class(1) |       0.7113 |
# +----------+--------------+

# %% [markdown]
# ### 6. Сравнение результатов с baseline-моделью (например, наивный байесовский классификатор из scikit-learn) по метрикам accuracy или log-likelihood.

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB, ComplementNB, CategoricalNB

# # Для непрерывных данных
# gnb = GaussianNB()

# Для текстовых данных/частот
mnb = MultinomialNB()
# mnb = MultinomialNB(alpha=1.0)  # alpha - параметр сглаживания

# # Для бинарных данных
# bnb = BernoulliNB()

# Вариант MultinomialNB, лучше работающий на несбалансированных данных.
comnb = ComplementNB()

# Для категориальных данных.
catnb = CategoricalNB()

# %%
from sklearn.model_selection import train_test_split


mnb.fit(X_train, y_train)
comnb.fit(X_train, y_train)
catnb.fit(X_train, y_train)
# probabilities = model_h_m.predict_proba(X)
# Out:
# CategoricalNB()

# %%
from sklearn.metrics import accuracy_score

y_pred_mnb = mnb.predict(X_test)
accuracy_mnb = accuracy_score(y_test, y_pred_mnb)
print(f"MultinomialNB: {accuracy_mnb:.4f}")

y_pred_comnb = comnb.predict(X_test)
accuracy_comnb = accuracy_score(y_test, y_pred_comnb)
print(f"ComplementNB: {accuracy_comnb:.4f}")

y_pred_catnb = catnb.predict(X_test)
accuracy_catnb = accuracy_score(y_test, y_pred_mnb)
print(f"CategoricalNB: {accuracy_catnb:.4f}")

# 4.2. Предсказание для Байесовской сети
# Для предсказания в БС нужен inference engine.
inference = VariableElimination(model_h_m)
y_pred_bn = []

for i, test_case in X_test.iterrows():
    evidence_dict = test_case.to_dict()
    query = inference.map_query(variables=['class'], evidence=evidence_dict, show_progress=False)
    y_pred_bn.append(query['class'])

# y_pred_bn = pd.Series(y_pred_bn)
accuracy_bn = accuracy_score(y_test, y_pred_bn)
print(f"BayesianNetwork: {accuracy_bn:.4f}")
# Out:
# MultinomialNB: 0.8154
# ComplementNB: 0.8160
# CategoricalNB: 0.8154
# BayesianNetwork: 0.9975

# %% [markdown]
# ### 7. Калькулятор Limme

# %%
import lime
import lime.lime_tabular
import pandas as pd
import numpy as np


explainer = lime.lime_tabular.LimeTabularExplainer(
    X_train.values, 
    feature_names=X_train.columns, 
    mode='classification',
    discretize_continuous=True,
    sample_around_instance=True,
    random_state=RND_SEED
)

x_test = pd.DataFrame(np.zeros((1, len(X.columns))), columns=X_train.columns)

flag = 1
for col, mapping in mappings.items():
    if flag:
        flag = 0
        continue
    print(f"Столбец '{col}':")
    for value, encoded in mapping.items():
        print(f"  {value} -> {encoded}")
    print("Выберите значение данного признака (число): ", end="")
    number = input()
    if number == '':
        number = 0
    else:
        number = int(number)
    print(number)
    x_test.loc[0, col] = number

print(x_test.head(5))
exp = explainer.explain_instance(x_test.values[0], mnb.predict_proba, num_features=22)
# Out:
# Столбец 'cap-shape':
#   b -> 0
#   c -> 1
#   f -> 2
#   k -> 3
#   s -> 4
#   x -> 5
# Выберите значение данного признака (число): 0
# Столбец 'cap-surface':
#   f -> 0
#   g -> 1
#   s -> 2
#   y -> 3
# Выберите значение данного признака (число): 3
# Столбец 'cap-color':
#   b -> 0
#   c -> 1
#   e -> 2
#   g -> 3
#   n -> 4
#   p -> 5
#   r -> 6
#   u -> 7
#   w -> 8
#   y -> 9
# Выберите значение данного признака (число): 7
# Столбец 'bruises':
#   f -> 0
#   t -> 1
# Выберите значение данного признака (число): 1
# Столбец 'odor':
#   a -> 0
#   c -> 1
#   f -> 2
#   l -> 3
#   m -> 4
#   n -> 5
#   p -> 6
#   s -> 7
#   y -> 8
# Выберите значение данного признака (число): 8
# Столбец 'gill-attachment':
#   a -> 0
#   f -> 1
# Выберите значение данного признака (число): 1
# Столбец 'gill-spacing':
#   c -> 0
#   w -> 1
# Выберите значение данного признака (число): 0
# Столбец 'gill-size':
#   b -> 0
#   n -> 1
# Выберите значение данного признака (число): 0
# Столбец 'gill-color':
#   b -> 0
#   e -> 1
#   g -> 2
#   h -> 3
#   k -> 4
#   n -> 5
#   o -> 6
#   p -> 7
#   r -> 8
#   u -> 9
#   w -> 10
#   y -> 11
# Выберите значение данного признака (число): 6
# Столбец 'stalk-shape':
#   e -> 0
#   t -> 1
# Выберите значение данного признака (число): 1
# Столбец 'stalk-root':
#   ? -> 0
#   b -> 1
#   c -> 2
#   e -> 3
#   r -> 4
# Выберите значение данного признака (число): 3
# Столбец 'stalk-surface-above-ring':
#   f -> 0
#   k -> 1
#   s -> 2
#   y -> 3
# Выберите значение данного признака (число): 2
# Столбец 'stalk-surface-below-ring':
#   f -> 0
#   k -> 1
#   s -> 2
#   y -> 3
# Выберите значение данного признака (число): 2
# Столбец 'stalk-color-above-ring':
#   b -> 0
#   c -> 1
#   e -> 2
#   g -> 3
#   n -> 4
#   o -> 5
#   p -> 6
#   w -> 7
#   y -> 8
# Выберите значение данного признака (число): 6
# Столбец 'stalk-color-below-ring':
#   b -> 0
#   c -> 1
#   e -> 2
#   g -> 3
#   n -> 4
#   o -> 5
#   p -> 6
#   w -> 7
#   y -> 8
# Выберите значение данного признака (число): 5
# Столбец 'veil-type':
#   p -> 0
# Выберите значение данного признака (число): 0
# Столбец 'veil-color':
#   n -> 0
#   o -> 1
#   w -> 2
#   y -> 3
# Выберите значение данного признака (число): 2
# Столбец 'ring-number':
#   n -> 0
#   o -> 1
#   t -> 2
# Выберите значение данного признака (число): 1
# Столбец 'ring-type':
#   e -> 0
#   f -> 1
#   l -> 2
#   n -> 3
#   p -> 4
# Выберите значение данного признака (число): 4
# Столбец 'spore-print-color':
#   b -> 0
#   h -> 1
#   k -> 2
#   n -> 3
#   o -> 4
#   r -> 5
#   u -> 6
#   w -> 7
#   y -> 8
# Выберите значение данного признака (число): 6
# Столбец 'population':
#   a -> 0
#   c -> 1
#   n -> 2
#   s -> 3
#   v -> 4
#   y -> 5
# Выберите значение данного признака (число): 4
# Столбец 'habitat':
#   d -> 0
#   g -> 1
#   l -> 2
#   m -> 3
#   p -> 4
#   u -> 5
#   w -> 6
# Выберите значение данного признака (число): 5
#    cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0        0.0          3.0        7.0      1.0   8.0              1.0
#
#    gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 0           0.0        0.0         6.0          1.0  ...
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# 0                       2.0                     6.0                     5.0
#
#    veil-type  veil-color  ring-number  ring-type  spore-print-color  \
# 0        0.0         2.0          1.0        4.0                6.0
#
#    population  habitat
# 0         4.0      5.0
#
# [1 rows x 22 columns]
# C:\Users\JustDema\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but MultinomialNB was fitted with feature names
#   warnings.warn(

# %%
import matplotlib.pyplot as plt

print("Предсказанный класс:", mnb.predict(x_test)[0])
print("Вероятности:", mnb.predict_proba(x_test)[0])


# Получить данные для визуализации
features_with_weights = exp.as_list()
features = [f[0] for f in features_with_weights]
weights = [f[1] for f in features_with_weights]

# Создать график
plt.figure(figsize=(10, 6))
colors = ['green' if w > 0 else 'red' for w in weights]
bars = plt.barh(features, weights, color=colors)

plt.axvline(x=0, color='black', linestyle='-', alpha=0.3)
plt.xlabel('Влияние на предсказание')
plt.title(f'Объяснение LIME\nПредсказанный класс: {mnb.predict(x_test)[0]}, Вероятность: {mnb.predict_proba(x_test)[0][mnb.predict(x_test)[0]]:.3f}')
plt.grid(axis='x', alpha=0.3)


plt.tight_layout()
plt.show()
# Out:
# Предсказанный класс: 0
# Вероятности: [0.82773566 0.17226434]
